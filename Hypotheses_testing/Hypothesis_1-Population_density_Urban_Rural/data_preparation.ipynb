# %%
# Import Dependencies
from pathlib import Path
import pandas as pd
import requests
import json
from api_key import open_weather_api_key
import numpy as np
from datetime import datetime, timedelta
import calendar
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#Create a path variable to the data
cities_path = Path('Resources/32180DS0001_2001-21.xlsx')

# %%
# Import the data into a Pandas DataFrame
cities_data_df = pd.read_excel(cities_path, sheet_name="Table 1")
cities_data_df.head(20)
# Out:
#                       Australian Bureau of Statistics       Unnamed: 1  \
# 0                           Regional population, 2021              NaN
# 1    Released at 11.30am (Canberra time) 26 July 2022              NaN
# 2   Table 1. Estimated resident population, Statis...              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                            S/T code         S/T name
# 7                                                 NaN              NaN
# 8                                                   1  New South Wales
# 9                                                   1  New South Wales
# 10                                                  1  New South Wales
# 11                                                  1  New South Wales
# 12                                                  1  New South Wales
# 13                                                  1  New South Wales
# 14                                                  1  New South Wales
# 15                                                  1  New South Wales
# 16                                                  1  New South Wales
# 17                                                  1  New South Wales
# 18                                                  1  New South Wales
# 19                                                  1  New South Wales
#
#     Unnamed: 2   Unnamed: 3 Unnamed: 4      Unnamed: 5 Unnamed: 6  \
# 0          NaN          NaN        NaN             NaN        NaN
# 1          NaN          NaN        NaN             NaN        NaN
# 2          NaN          NaN        NaN             NaN        NaN
# 3          NaN          NaN        NaN             NaN        NaN
# 4          NaN          NaN        NaN             NaN        NaN
# 5          NaN          NaN        NaN             NaN        NaN
# 6   GCCSA code   GCCSA name   SA4 code        SA4 name   SA3 code
# 7          NaN          NaN        NaN             NaN        NaN
# 8        1RNSW  Rest of NSW        101  Capital Region      10102
# 9        1RNSW  Rest of NSW        101  Capital Region      10102
# 10       1RNSW  Rest of NSW        101  Capital Region      10102
# 11       1RNSW  Rest of NSW        101  Capital Region      10102
# 12       1RNSW  Rest of NSW        101  Capital Region      10102
# 13       1RNSW  Rest of NSW        101  Capital Region      10102
# 14       1RNSW  Rest of NSW        101  Capital Region      10102
# 15       1RNSW  Rest of NSW        101  Capital Region      10103
# 16       1RNSW  Rest of NSW        101  Capital Region      10103
# 17       1RNSW  Rest of NSW        101  Capital Region      10103
# 18       1RNSW  Rest of NSW        101  Capital Region      10103
# 19       1RNSW  Rest of NSW        101  Capital Region      10104
#
#          Unnamed: 7 Unnamed: 8            Unnamed: 9  ... Unnamed: 32  \
# 0               NaN        NaN                   NaN  ...         NaN
# 1               NaN        NaN                   NaN  ...         NaN
# 2               NaN        NaN                   NaN  ...         NaN
# 3               NaN        NaN                   NaN  ...         NaN
# 4               NaN        NaN                   NaN  ...      Change
# 5               NaN        NaN                   NaN  ...   2011-2021
# 6          SA3 name   SA2 code              SA2 name  ...         no.
# 7               NaN        NaN                   NaN  ...         NaN
# 8        Queanbeyan  101021007             Braidwood  ...         872
# 9        Queanbeyan  101021008               Karabar  ...        -546
# 10       Queanbeyan  101021009            Queanbeyan  ...         655
# 11       Queanbeyan  101021010           Queanbeyan   ...         142
# 12       Queanbeyan  101021012      Queanbeyan West   ...        -480
# 13       Queanbeyan  101021610               Googong  ...        6194
# 14       Queanbeyan  101021611  Queanbeyan Surrounds  ...        1962
# 15  Snowy Mountains  101031013               Bombala  ...         -35
# 16  Snowy Mountains  101031014                 Cooma  ...        -175
# 17  Snowy Mountains  101031015       Cooma Surrounds  ...         189
# 18  Snowy Mountains  101031016            Jindabyne   ...        1139
# 19      South Coast  101041017          Batemans Bay  ...         815
#
#    Unnamed: 33 Unnamed: 34 Unnamed: 35              Unnamed: 36 Unnamed: 37  \
# 0          NaN         NaN         NaN                      NaN         NaN
# 1          NaN         NaN         NaN                      NaN         NaN
# 2          NaN         NaN         NaN                      NaN         NaN
# 3          NaN         NaN         NaN                      NaN         NaN
# 4          NaN         NaN         NaN                      NaN         NaN
# 5          NaN         NaN        Area  Population density 2021         NaN
# 6            %         NaN         km2              persons/km2         NaN
# 7          NaN         NaN         NaN                      NaN         NaN
# 8         25.2         NaN      3418.4                      1.3         NaN
# 9           -6         NaN           7                   1223.9         NaN
# 10         6.1         NaN         4.8                   2387.7         NaN
# 11         2.9         NaN          13                    391.7         NaN
# 12        -3.6         NaN        13.7                    931.9         NaN
# 13     12145.1         NaN         6.9                    902.9         NaN
# 14        13.5         NaN      3047.7                      5.4         NaN
# 15        -1.4         NaN      3990.1                      0.6         NaN
# 16        -2.5         NaN       103.6                     65.2         NaN
# 17         5.8         NaN        6251                      0.6         NaN
# 18        16.5         NaN      3939.8                        2         NaN
# 19        10.5         NaN        63.7                    134.8         NaN
#
#    Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
#
# [20 rows x 42 columns]

# %%
#Clean the dataframe
dropped_row_cities_df = cities_data_df.iloc[8:2462]
dropped_column_cities_df = dropped_row_cities_df[["Unnamed: 1","Unnamed: 9","Unnamed: 30","Unnamed: 35","Unnamed: 36"]]
cleaned_cities_df = dropped_column_cities_df.rename(columns={"Unnamed: 1": "State Name", "Unnamed: 9": "Statistical Areas Level 2 Name", "Unnamed: 30": "Population", "Unnamed: 35": "Area km2","Unnamed: 36": "Population Density (Persons/km2)"}).reset_index()
del cleaned_cities_df["index"]
cleaned_cities_df
# Out:
#                         State Name Statistical Areas Level 2 Name Population  \
# 0                  New South Wales                      Braidwood       4330
# 1                  New South Wales                        Karabar       8546
# 2                  New South Wales                     Queanbeyan      11370
# 3                  New South Wales                    Queanbeyan        5093
# 4                  New South Wales               Queanbeyan West       12743
# ...                            ...                            ...        ...
# 2449  Australian Capital Territory                        Namadgi         67
# 2450             Other Territories               Christmas Island       1716
# 2451             Other Territories        Cocos (Keeling) Islands        602
# 2452             Other Territories                     Jervis Bay        310
# 2453             Other Territories                 Norfolk Island       2220
#
#      Area km2 Population Density (Persons/km2)
# 0      3418.4                              1.3
# 1           7                           1223.9
# 2         4.8                           2387.7
# 3          13                            391.7
# 4        13.7                            931.9
# ...       ...                              ...
# 2449   1202.8                              0.1
# 2450    136.1                             12.6
# 2451     13.7                             43.9
# 2452     67.2                              4.6
# 2453     38.7                             57.4
#
# [2454 rows x 5 columns]

# %%
#Getting latitude and longitude data 

cities_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{cities_url}appid={open_weather_api_key}&units={units}&q="

# set up lists to hold reponse info
lat = []
lon = []

# Loop through the list of cities and perform a request for data on each
for index, row in cleaned_cities_df.iterrows():
    city = row["Statistical Areas Level 2 Name"]
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
    except:
        lat.append(np.nan)
        lon.append(np.nan)

# %%
#Add Latitude and Longitude to the dataframe
cleaned_cities_df["Latitude"] = lat
cleaned_cities_df["Longitude"] = lon
cleaned_cities_df
# Out:
#                         State Name Statistical Areas Level 2 Name Population  \
# 0                  New South Wales                      Braidwood       4330
# 1                  New South Wales                        Karabar       8546
# 2                  New South Wales                     Queanbeyan      11370
# 3                  New South Wales                    Queanbeyan        5093
# 4                  New South Wales               Queanbeyan West       12743
# ...                            ...                            ...        ...
# 2449  Australian Capital Territory                        Namadgi         67
# 2450             Other Territories               Christmas Island       1716
# 2451             Other Territories        Cocos (Keeling) Islands        602
# 2452             Other Territories                     Jervis Bay        310
# 2453             Other Territories                 Norfolk Island       2220
#
#      Area km2 Population Density (Persons/km2)  Latitude  Longitude
# 0      3418.4                              1.3   41.2650   -88.2123
# 1           7                           1223.9  -35.3753   149.2308
# 2         4.8                           2387.7  -35.3500   149.2333
# 3          13                            391.7  -35.3500   149.2333
# 4        13.7                            931.9       NaN        NaN
# ...       ...                              ...       ...        ...
# 2449   1202.8                              0.1       NaN        NaN
# 2450    136.1                             12.6  -10.5000   105.6667
# 2451     13.7                             43.9       NaN        NaN
# 2452     67.2                              4.6  -35.1333   150.7000
# 2453     38.7                             57.4  -29.0333   167.9500
#
# [2454 rows x 7 columns]

# %%
#Clean new dataframe
cities_data_final_df = cleaned_cities_df.dropna(how="any").reset_index()
del cities_data_final_df['index']
cities_data_final_df
# Out:
#                         State Name Statistical Areas Level 2 Name Population  \
# 0                  New South Wales                      Braidwood       4330
# 1                  New South Wales                        Karabar       8546
# 2                  New South Wales                     Queanbeyan      11370
# 3                  New South Wales                    Queanbeyan        5093
# 4                  New South Wales                        Googong       6245
# ...                            ...                            ...        ...
# 1795  Australian Capital Territory                       Molonglo          0
# 1796  Australian Capital Territory                         Wright       3806
# 1797             Other Territories               Christmas Island       1716
# 1798             Other Territories                     Jervis Bay        310
# 1799             Other Territories                 Norfolk Island       2220
#
#      Area km2 Population Density (Persons/km2)  Latitude  Longitude
# 0      3418.4                              1.3   41.2650   -88.2123
# 1           7                           1223.9  -35.3753   149.2308
# 2         4.8                           2387.7  -35.3500   149.2333
# 3          13                            391.7  -35.3500   149.2333
# 4         6.9                            902.9  -35.4177   149.2334
# ...       ...                              ...       ...        ...
# 1795      2.2                                0  -35.2998   149.0402
# 1796      1.3                           2993.1   45.1833   -93.9502
# 1797    136.1                             12.6  -10.5000   105.6667
# 1798     67.2                              4.6  -35.1333   150.7000
# 1799     38.7                             57.4  -29.0333   167.9500
#
# [1800 rows x 7 columns]

# %%
#Set up a list of time frame from Jan 2023 to Jan 2024 mothly
start_date = '2021-01-06'
end_date = '2022-01-01'
time = np.arange(np.datetime64(start_date), np.datetime64(end_date),timedelta(days=30))
ux_time = time.astype('datetime64[s]').astype('int')
ux_time
# Out:
# array([1609891200, 1612483200, 1615075200, 1617667200, 1620259200,
#        1622851200, 1625443200, 1628035200, 1630627200, 1633219200,
#        1635811200, 1638403200])

# %%
#Create empty list for storing data
co = []
o3 =[]
no2 =[]
so2 = []
pm2_5 = []
pm10 = []


#Loop through all cities/row in dataframe
for index, row in cleaned_cities_df.iterrows():
    lat = row["Latitude"]
    lon =row["Longitude"]
    #Loop through all time in time frame
    for i in range(len(ux_time)):
        start = ux_time[i]
        end = start+ 1
        daily_url = f"http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={open_weather_api_key}"
        data = requests.get(daily_url).json()
        try: 
            #Add data to respective lists
            co.append(data["list"][0]["components"]['co'])
            o3.append(data["list"][0]["components"]['o3'])
            no2.append(data["list"][0]["components"]['no2'])
            so2.append(data["list"][0]["components"]['so2'])
            pm2_5.append(data["list"][0]["components"]['pm2_5'])
            pm10.append(data["list"][0]["components"]['pm10'])    
        except (KeyError, IndexError):
            co.append(np.nan)
            o3.append(np.nan)
            no2.append(np.nan)
            so2.append(np.nan)
            pm2_5.append(np.nan)
            pm10.append(np.nan) 

    #Calculate average data
    clean_co = [x for x in co if not np.isnan(x)]
    clean_o3 = [x for x in o3 if not np.isnan(x)]
    clean_no2 = [x for x in no2 if not np.isnan(x)]
    clean_so2 = [x for x in so2 if not np.isnan(x)]
    clean_pm2_5 = [x for x in pm2_5 if not np.isnan(x)]
    clean_pm10 = [x for x in pm10 if not np.isnan(x)]

    average_co = sum(clean_co) / len(clean_co)
    average_o3 = sum(clean_o3) / len(clean_o3)
    average_no2 = sum(clean_no2) / len(clean_no2)
    average_so2 = sum(clean_so2) / len(clean_so2)
    average_pm2_5 = sum(clean_pm2_5) / len(clean_pm2_5)
    average_pm10 = sum(clean_pm10) / len(clean_pm10)
    
    #Add data to dataframe
    cities_data_final_df.loc[index, "Average CO (μg/m3)"] = average_co
    cities_data_final_df.loc[index, "Average O3 (μg/m3)"] = average_o3
    cities_data_final_df.loc[index, "Average NO2 (μg/m3)"] = average_no2
    cities_data_final_df.loc[index, "Average S02 (μg/m3)"] = average_so2
    cities_data_final_df.loc[index, "Average PM2.5 (μg/m3)"] = average_pm2_5
    cities_data_final_df.loc[index, "Average PM10 (μg/m3)"] = average_pm10

# %%
#Drop NaN values
cities_data_final_df = cities_data_final_df.dropna(how="any")
cities_data_final_df
# Out:
#                         State Name Statistical Areas Level 2 Name Population  \
# 0                  New South Wales                      Braidwood       4330
# 1                  New South Wales                        Karabar       8546
# 2                  New South Wales                     Queanbeyan      11370
# 3                  New South Wales                    Queanbeyan        5093
# 4                  New South Wales                        Googong       6245
# ...                            ...                            ...        ...
# 1795  Australian Capital Territory                       Molonglo          0
# 1796  Australian Capital Territory                         Wright       3806
# 1797             Other Territories               Christmas Island       1716
# 1798             Other Territories                     Jervis Bay        310
# 1799             Other Territories                 Norfolk Island       2220
#
#      Area km2 Population Density (Persons/km2)  Latitude  Longitude  \
# 0      3418.4                              1.0   41.2650   -88.2123
# 1           7                          1,224.0  -35.3753   149.2308
# 2         4.8                          2,388.0  -35.3500   149.2333
# 3          13                            392.0  -35.3500   149.2333
# 4         6.9                            903.0  -35.4177   149.2334
# ...       ...                              ...       ...        ...
# 1795      2.2                              0.0  -35.2998   149.0402
# 1796      1.3                          2,993.0   45.1833   -93.9502
# 1797    136.1                             13.0  -10.5000   105.6667
# 1798     67.2                              5.0  -35.1333   150.7000
# 1799     38.7                             57.0  -29.0333   167.9500
#
#       Average CO (μg/m3)  Average O3 (μg/m3)  Average NO2 (μg/m3)  \
# 0             283.442500           72.566667             8.796667
# 1             255.904583           55.647917             6.565417
# 2             246.725278           50.008333             5.821667
# 3             242.135625           47.188542             5.449792
# 4             242.135625           47.188542             5.449792
# ...                  ...                 ...                  ...
# 1795          253.008652           42.785339             8.280131
# 1796          252.990538           42.776613             8.279230
# 1797          253.006920           42.763641             8.282959
# 1798          252.988835           42.754944             8.282057
# 1799          253.019129           42.751197             8.287067
#
#       Average S02 (μg/m3)  Average PM2.5 (μg/m3)  Average PM10 (μg/m3)
# 0                1.959167               8.870000              9.447500
# 1                1.588750               6.675000              7.647500
# 2                1.465278               5.943333              7.047500
# 3                1.403542               5.577500              6.747500
# 4                1.403542               5.577500              6.747500
# ...                   ...                    ...                   ...
# 1795             3.799508               4.958023              7.525435
# 1796             3.797958               4.956432              7.523417
# 1797             3.797872               4.955646              7.522579
# 1798             3.796325               4.954060              7.520567
# 1799             3.798710               4.956698              7.524548
#
# [1800 rows x 13 columns]

# %%
# Save the clean DataFrame to a CSV file without the index.
cities_data_final_df.to_csv("Output/air_quality.csv", index=False)
